# %% [markdown]
# ## Incident Management Data

# %%
import pandas as pd
import numpy as np
# Out:
# Running cells with 'cpython-3.14.3-windows-x86_64-none (3.14.3) (Python 3.14.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/pinnu/AppData/Roaming/uv/python/cpython-3.14.3-windows-x86_64-none/python.exe -m pip install ipykernel -U --force-reinstall'
